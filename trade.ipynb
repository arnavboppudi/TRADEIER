# %%
import numpy as np
import requests
import json

# %% [markdown]
# ### import keys

# %%
from keys import *

# %%
import requests

response = requests.get('https://sandbox.tradier.com/v1/markets/options/chains',
    params={'symbol': 'AAPL', 'expiration': '2023-08-25', 'greeks': 'true'},
    headers={'Authorization': 'Bearer vmQ4pJcFMITMdz9zBn1yBFys5j7V', 'Accept': 'application/json'}
)
json_response = response.json()
response.status_code
json_response
# Out:
# {'options': {'option': [{'symbol': 'AAPL230825P00050000',
#     'description': 'AAPL Aug 25 2023 $50.00 Put',
#     'exch': 'Z',
#     'type': 'option',
#     'last': 0.01,
#     'change': 0.0,
#     'volume': 20,
#     'open': 0.01,
#     'high': 0.01,
#     'low': 0.01,
#     'close': None,
#     'bid': 0.0,
#     'ask': 0.01,
#     'underlying': 'AAPL',
#     'strike': 50.0,
#     'greeks': {'delta': -7.5e-15,
#      'gamma': -1.1279401756652354e-14,
#      'theta': -0.013162936056009303,
#      'vega': 1.999999283901307e-05,
#      'rho': 0.004167397093571679,
#      'phi': -0.014784441617621269,
#      'bid_iv': 0.0,
#      'mid_iv': 0.0,
#      'ask_iv': 0.0,
#      'smv_vol': 0.458,
#      'updated_at': '2023-08-22 18:58:52'},
#     'change_percentage': 0.0,
#     'average_volume': 0,
#     'last_volume': 15,
#     'trade_date': 1692720187699,
#     'prevclose': 0.01,
#     'week_52_high': 0.0,
#     'week_52_low': 0.0,
#     'bidsize': 0,
#     'bidexch': 'P',
# ...

# %%
import pandas as pd

data = {
    'options': {
        'option': [{
            'symbol': 'AAPL230825P00050000',
            'description': 'AAPL Aug 25 2023 $50.00 Put',
            'exch': 'Z',
            # ... (other data)
            'smv_vol': 0.458,
            'contract_size': 100,
            'expiration_date': '2023-08-25',
            'expiration_type': 'weeklys',
            'option_type': 'call',
            'root_symbol': 'AAPL'
        }]
        #... (other data if any)
    }
}

df = pd.DataFrame(data['options']['option'])

df
# Out:
#                 symbol                  description exch  smv_vol  \
# 0  AAPL230825P00050000  AAPL Aug 25 2023 $50.00 Put    Z    0.458
#
#    contract_size expiration_date expiration_type option_type root_symbol
# 0            100      2023-08-25         weeklys        call        AAPL
